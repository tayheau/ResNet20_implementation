# %%
# !pwd
# !cd /content/drive/MyDrive/term_project_DL
# Out:
# /content

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/term_project_DL/
# Out:
# /content/drive/MyDrive/term_project_DL

# %%
# !unzip Term_Project-1.zip
# Out:
# Archive:  Term_Project-1.zip
#    creating: checkpoints/
#   inflating: checkpoints/model.pth
#    creating: data/
#   inflating: model.py
#   inflating: result.txt
#   inflating: run.py
#   inflating: test.py
#    creating: test_images/
#   inflating: test_images/0000.jpg
#   inflating: test_images/0001.jpg
#   inflating: test_images/0002.jpg
#   inflating: test_images/0003.jpg
#   inflating: test_images/0004.jpg
#   inflating: test_images/0005.jpg
#   inflating: test_images/0006.jpg
#   inflating: test_images/0007.jpg
#   inflating: test_images/0008.jpg
#   inflating: test_images/0009.jpg
#   inflating: test_images/0010.jpg
#   inflating: test_images/0011.jpg
#   inflating: test_images/0012.jpg
#   inflating: test_images/0013.jpg
#   inflating: test_images/0014.jpg
#   inflating: test_images/0015.jpg
#   inflating: test_images/0016.jpg
#   inflating: test_images/0017.jpg
#   inflating: test_images/0018.jpg
#   inflating: test_images/0019.jpg
#   inflating: test_images/0020.jpg
# ...

# %%
# !python train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 400
# learning_rate: 0.01
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0% 0/125 [00:00<?, ?it/s]
# [Epoch 1 / 8]
#   0% 0/125 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/term_project_DL/train.py", line 123, in <module>
#     train(args, train_loader, model)
#   File "/content/drive/MyDrive/term_project_DL/train.py", line 44, in train
#     output = model(image)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/content/drive/MyDrive/term_project_DL/model.py", line 111, in forward
#     out = F.relu(self.bn1(self.conv1(x)))
# NameError: name 'F' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python test.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 100% 2500/2500 [00:09<00:00, 262.83it/s]
# Test Accuracy : 0.83100

# %%
# !python run.py
# Out:
#   0% 0/7 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/term_project_DL/run.py", line 77, in <module>
#     preds = inference(args, test_loader, model)
#   File "/content/drive/MyDrive/term_project_DL/run.py", line 40, in inference
#     for i, x in enumerate(pbar):
#   File "/usr/local/lib/python3.10/dist-packages/tqdm/std.py", line 1178, in __iter__
#     for obj in iterable:
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 633, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 677, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py", line 54, in fetch
#     return self.collate_fn(data)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/collate.py", line 265, in default_collate
# ...

# %%
# !ls
# Out:
# checkpoints  __pycache__  Term_Project-1.zip  train.py
# data	     result.txt   test_images	      Untitled0.ipynb
# model.py     run.py	  test.py	      utils

# %%
# %cd /content/drive/MyDrive/term_project_DL
# Out:
# /content/drive/MyDrive/term_project_DL

# %%
# !python train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 5
# learning_rate: 0.01
# Epochs: 20
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0% 0/10000 [00:00<?, ?it/s]
# [Epoch 1 / 20]
# 100% 10000/10000 [01:32<00:00, 107.68it/s]
# Epoch 1
# train_loss : 1.2419803184044547
# train_accuracy : 57.856
# last lr : 0.001
# Validation_loss : 0.164
# Validation_accuracy : 72.060
# [Epoch 2 / 20]
# 100% 10000/10000 [01:25<00:00, 116.51it/s]
# Epoch 2
# train_loss : 0.9462627447956242
# train_accuracy : 69.514
# last lr : 0.003
# Validation_loss : 0.142
# Validation_accuracy : 76.538
# [Epoch 3 / 20]
# 100% 10000/10000 [01:26<00:00, 116.06it/s]
# Epoch 3
# train_loss : 0.7623108031128301
# train_accuracy : 74.670
# last lr : 0.005
# Validation_loss : 0.157
# Validation_accuracy : 73.864
# [Epoch 4 / 20]
# 100% 10000/10000 [01:26<00:00, 115.99it/s]
# Epoch 4
# train_loss : 0.735021438903315
# train_accuracy : 75.464
# ...

# %% [markdown]
# # hyperparameters
#     args.epochs = 20
#     args.learning_rate = 0.01
#     args.batch_size = 5

# %%
# !python test.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 100% 2500/2500 [02:33<00:00, 16.28it/s]
# Test Accuracy : 0.89810

# %%
# !python run.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/term_project_DL/run.py", line 68, in <module>
#     model.load_state_dict(torch.load(args.load_model))
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 809, in load
#     return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 1172, in _load
#     result = unpickler.load()
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 1142, in persistent_load
#     typed_storage = load_tensor(dtype, nbytes, key, _maybe_decode_ascii(location))
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 1116, in load_tensor
#     wrap_storage=restore_location(storage, location),
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 217, in default_restore_location
#     result = fn(storage, location)
# ...

# %%
# !python train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 50
# learning_rate: 0.01
# Epochs: 20
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0% 0/1000 [00:00<?, ?it/s]
# [Epoch 1 / 20]
# 100% 1000/1000 [00:36<00:00, 27.71it/s]
# Epoch 1
# train_loss : 1.059542953044176
# train_accuracy : 62.864
# last lr : 0.001
# [Epoch 2 / 20]
# 100% 1000/1000 [00:34<00:00, 29.08it/s]
# Epoch 2
# train_loss : 0.7494255036115647
# train_accuracy : 74.840
# last lr : 0.003
# [Epoch 3 / 20]
# 100% 1000/1000 [00:34<00:00, 28.94it/s]
# Epoch 3
# train_loss : 0.6725881849527359
# train_accuracy : 77.926
# last lr : 0.005
# [Epoch 4 / 20]
# 100% 1000/1000 [00:34<00:00, 29.13it/s]
# Epoch 4
# train_loss : 0.5447258025407791
# train_accuracy : 82.056
# last lr : 0.008
# [Epoch 5 / 20]
# 100% 1000/1000 [00:34<00:00, 28.90it/s]
# Epoch 5
# train_loss : 0.43043658377230165
# train_accuracy : 85.496
# last lr : 0.009
# [Epoch 6 / 20]
# ...

# %% [markdown]
# # hyperparameters for the above
#
#     args.epochs = 20
#     args.learning_rate = 0.01
#     args.batch_size = 5

# %%
in

# %%
# !python train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 400
# learning_rate: 0.01
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0% 0/125 [00:00<?, ?it/s]
# [Epoch 1 / 8]
# 100% 125/125 [00:22<00:00,  5.66it/s]
# Epoch 1
# train_loss : 1.5428737745285035
# train_accuracy : 43.552
# [Epoch 2 / 8]
# 100% 125/125 [00:20<00:00,  6.22it/s]
# Epoch 2
# train_loss : 1.1020301766395568
# train_accuracy : 60.288
# [Epoch 3 / 8]
# 100% 125/125 [00:20<00:00,  6.24it/s]
# Epoch 3
# train_loss : 0.8641788353919982
# train_accuracy : 69.494
# [Epoch 4 / 8]
# 100% 125/125 [00:20<00:00,  6.01it/s]
# Epoch 4
# train_loss : 0.687011911392212
# train_accuracy : 75.938
# [Epoch 5 / 8]
# 100% 125/125 [00:21<00:00,  5.94it/s]
# Epoch 5
# train_loss : 0.5619267113208771
# train_accuracy : 80.626
# [Epoch 6 / 8]
# 100% 125/125 [00:20<00:00,  6.03it/s]
# Epoch 6
# train_loss : 0.4452453474998474
# train_accuracy : 84.634
# ...

# %%
# !python test.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 100% 2500/2500 [00:12<00:00, 193.29it/s]
# Test Accuracy : 0.83140

# %%
# !python plot.py
# Out:
# Figure(640x480)

# %%
# %matplotlib inline
# !python plot.py
# Out:
# python3: can't open file '/content/drive/MyDrive/term_project_DL/plot.py': [Errno 2] No such file or directory

# %% [markdown]
# #ResNet20 bellow  model A-1
#
# hyper param :
# * args.epochs = 8
# * args.learning_rate = 0.01
# * args.batch_size = 400
#
#
# NO pre data normalization

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 400
# learning_rate: 0.01
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/125 [00:00<?, ?it/s]
# [Epoch 1 / 8]
# 100%|██████████| 125/125 [00:22<00:00,  5.68it/s]
# Epoch 1
# train_loss : 1.5675036916732787
# train_accuracy : 41.628
# [Epoch 2 / 8]
# 100%|██████████| 125/125 [00:20<00:00,  6.20it/s]
# Epoch 2
# train_loss : 1.0784332098960876
# train_accuracy : 61.504
# [Epoch 3 / 8]
# 100%|██████████| 125/125 [00:20<00:00,  6.15it/s]
# Epoch 3
# train_loss : 0.8457475018501281
# train_accuracy : 69.942
# [Epoch 4 / 8]
# 100%|██████████| 125/125 [00:20<00:00,  6.11it/s]
# Epoch 4
# train_loss : 0.6777257189750672
# train_accuracy : 76.266
# [Epoch 5 / 8]
# 100%|██████████| 125/125 [00:20<00:00,  5.99it/s]
# Epoch 5
# train_loss : 0.554966413974762
# train_accuracy : 80.710
# [Epoch 6 / 8]
# ...

# %%
# !python test.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 100% 2500/2500 [00:09<00:00, 264.17it/s]
# Test Accuracy : 0.83470

# %% [markdown]
#    # hyperparameters ResNet20 bellow
#
#     args.epochs = 16
#     args.learning_rate = 0.01
#     args.batch_size = 200

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 200
# learning_rate: 0.01
# Epochs: 16
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/250 [00:00<?, ?it/s]
# [Epoch 1 / 16]
# 100%|██████████| 250/250 [00:20<00:00, 12.44it/s]
# Epoch 1
# train_loss : 1.4774386887550355
# train_accuracy : 45.168
# [Epoch 2 / 16]
# 100%|██████████| 250/250 [00:20<00:00, 12.29it/s]
# Epoch 2
# train_loss : 1.077748745918274
# train_accuracy : 61.126
# [Epoch 3 / 16]
# 100%|██████████| 250/250 [00:19<00:00, 12.66it/s]
# Epoch 3
# train_loss : 0.9020943503379821
# train_accuracy : 68.076
# [Epoch 4 / 16]
# 100%|██████████| 250/250 [00:20<00:00, 12.18it/s]
# Epoch 4
# train_loss : 0.7510685663223267
# train_accuracy : 73.746
# [Epoch 5 / 16]
# 100%|██████████| 250/250 [00:19<00:00, 12.63it/s]
# Epoch 5
# train_loss : 0.6365922805070877
# train_accuracy : 77.938
# [Epoch 6 / 16]
# ...

# %%
# !python test.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 100% 2500/2500 [00:09<00:00, 252.56it/s]
# Test Accuracy : 0.85150

# %%
# !python run.py
# Out:
# 100% 7/7 [00:01<00:00,  5.23it/s]

# %% [markdown]
# # hyperparameters ResNet20 bellow + data augment
#
#
#     args.epochs = 16
#     args.learning_rate = 0.01
#     args.batch_size = 200

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 200
# learning_rate: 0.01
# Epochs: 16
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/250 [00:00<?, ?it/s]
# [Epoch 1 / 16]
# 100%|██████████| 250/250 [00:19<00:00, 12.52it/s]
# Epoch 1
# train_loss : 1.5216287922859193
# train_accuracy : 44.084
# [Epoch 2 / 16]
# 100%|██████████| 250/250 [00:21<00:00, 11.86it/s]
# Epoch 2
# train_loss : 1.0872263398170472
# train_accuracy : 60.920
# [Epoch 3 / 16]
# 100%|██████████| 250/250 [00:19<00:00, 12.66it/s]
# Epoch 3
# train_loss : 0.8843439447879792
# train_accuracy : 68.694
# [Epoch 4 / 16]
# 100%|██████████| 250/250 [00:20<00:00, 12.20it/s]
# Epoch 4
# train_loss : 0.7386125729084015
# train_accuracy : 74.308
# [Epoch 5 / 16]
# 100%|██████████| 250/250 [00:19<00:00, 12.65it/s]
# Epoch 5
# train_loss : 0.6380993274450302
# train_accuracy : 77.924
# [Epoch 6 / 16]
# ...

# %%
# !python test.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 100% 2500/2500 [00:11<00:00, 220.79it/s]
# Test Accuracy : 0.84610

# %% [markdown]
#   # hyperparameters ResNet20 + data augment
#     args.epochs = 8
#     args.learning_rate = 0.01
#     args.batch_size = 400

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 400
# learning_rate: 0.01
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/125 [00:00<?, ?it/s]
# [Epoch 1 / 8]
# 100%|██████████| 125/125 [00:21<00:00,  5.89it/s]
# Epoch 1
# train_loss : 1.533168948173523
# train_accuracy : 43.742
# [Epoch 2 / 8]
# 100%|██████████| 125/125 [00:20<00:00,  6.08it/s]
# Epoch 2
# train_loss : 1.0739305424690246
# train_accuracy : 61.382
# [Epoch 3 / 8]
# 100%|██████████| 125/125 [00:21<00:00,  5.95it/s]
# Epoch 3
# train_loss : 0.8431893582344056
# train_accuracy : 70.048
# [Epoch 4 / 8]
# 100%|██████████| 125/125 [00:20<00:00,  6.18it/s]
# Epoch 4
# train_loss : 0.6769235486984253
# train_accuracy : 76.244
# [Epoch 5 / 8]
# 100%|██████████| 125/125 [00:20<00:00,  5.96it/s]
# Epoch 5
# train_loss : 0.556603068113327
# train_accuracy : 80.366
# [Epoch 6 / 8]
# ...

# %%
# !python test.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 100% 2500/2500 [00:09<00:00, 253.42it/s]
# Test Accuracy : 0.82760

# %% [markdown]
#   # hyperparameters ResNet20 + data augment + validation
#     args.epochs = 8
#     args.learning_rate = 0.01
#     args.batch_size = 400

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 400
# learning_rate: 0.01
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/125 [00:00<?, ?it/s]
# [Epoch 1 / 8]
# 100%|██████████| 125/125 [00:20<00:00,  6.22it/s]
# Epoch 1
# train_loss : 1.5595449352264403
# train_accuracy : 42.374
# validation_loss : 1.973
# validation_accuracy : 39.330
# [Epoch 2 / 8]
# 100%|██████████| 125/125 [00:20<00:00,  6.13it/s]
# Epoch 2
# train_loss : 1.0904990286827088
# train_accuracy : 60.862
# validation_loss : 2.318
# validation_accuracy : 39.960
# [Epoch 3 / 8]
# 100%|██████████| 125/125 [00:19<00:00,  6.29it/s]
# Epoch 3
# train_loss : 0.8436743116378784
# train_accuracy : 69.878
# validation_loss : 1.150
# validation_accuracy : 62.790
# [Epoch 4 / 8]
# 100%|██████████| 125/125 [00:20<00:00,  6.03it/s]
# Epoch 4
# train_loss : 0.680832311630249
# train_accuracy : 76.002
# validation_loss : 0.883
# ...

# %%
# !python test.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 100% 2500/2500 [00:09<00:00, 250.23it/s]
# Test Accuracy : 0.82650

# %% [markdown]
#  # hyperparameters ResNet20 + data augment + validation
#     args.epochs = 14
#     args.learning_rate = 0.01
#     args.batch_size = 200

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 200
# learning_rate: 0.01
# Epochs: 14
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/250 [00:00<?, ?it/s]
# [Epoch 1 / 14]
# 100%|██████████| 250/250 [00:21<00:00, 11.90it/s]
# Epoch 1
# train_loss : 1.5321495280265809
# train_accuracy : 43.276
# validation_loss : 2.264
# validation_accuracy : 34.850
# [Epoch 2 / 14]
# 100%|██████████| 250/250 [00:21<00:00, 11.83it/s]
# Epoch 2
# train_loss : 1.0748248207569122
# train_accuracy : 61.254
# validation_loss : 1.139
# validation_accuracy : 59.770
# [Epoch 3 / 14]
# 100%|██████████| 250/250 [00:19<00:00, 12.52it/s]
# Epoch 3
# train_loss : 0.8790586748123169
# train_accuracy : 69.140
# validation_loss : 1.680
# validation_accuracy : 50.460
# [Epoch 4 / 14]
# 100%|██████████| 250/250 [00:20<00:00, 12.49it/s]
# Epoch 4
# train_loss : 0.7404648029804229
# train_accuracy : 74.072
# ...

# %% [markdown]
#  # hyperparameters ResNet20 + data augment + validation
#     args.epochs = 8
#     args.learning_rate = 0.01
#     args.batch_size = 500

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 500
# learning_rate: 0.01
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch 1 / 8]
# 100%|██████████| 100/100 [00:20<00:00,  4.81it/s]
# Epoch 1
# train_loss : 1.5295791256427764
# train_accuracy : 43.180
# validation_loss : 2.843
# validation_accuracy : 27.330
# [Epoch 2 / 8]
# 100%|██████████| 100/100 [00:20<00:00,  4.79it/s]
# Epoch 2
# train_loss : 1.0652735817432404
# train_accuracy : 61.784
# validation_loss : 1.851
# validation_accuracy : 44.760
# [Epoch 3 / 8]
# 100%|██████████| 100/100 [00:20<00:00,  4.91it/s]
# Epoch 3
# train_loss : 0.8591608726978301
# train_accuracy : 69.428
# validation_loss : 1.864
# validation_accuracy : 51.520
# [Epoch 4 / 8]
# 100%|██████████| 100/100 [00:20<00:00,  4.76it/s]
# Epoch 4
# train_loss : 0.6919720333814621
# train_accuracy : 75.610
# validation_loss : 0.983
# ...

# %% [markdown]
# validation test above may be too small

# %% [markdown]
#  # hyperparameters ResNet20 + data augment + validation A5
# * args.epochs = 8
# * args.learning_rate = 0.01
# * args.batch_size = 500
# * validation = 0.3 * test

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 500
# learning_rate: 0.01
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch 1 / 8]
# 100%|██████████| 100/100 [00:20<00:00,  4.86it/s]
# Epoch 1
# train_loss : 1.643704217672348
# train_accuracy : 39.178
# validation_loss : 3.171
# validation_accuracy : 28.940
# [Epoch 2 / 8]
# 100%|██████████| 100/100 [00:20<00:00,  4.99it/s]
# Epoch 2
# train_loss : 1.1338261884450913
# train_accuracy : 58.966
# validation_loss : 3.343
# validation_accuracy : 34.430
# [Epoch 3 / 8]
# 100%|██████████| 100/100 [00:20<00:00,  4.82it/s]
# Epoch 3
# train_loss : 0.8846199870109558
# train_accuracy : 68.490
# validation_loss : 0.989
# validation_accuracy : 66.260
# [Epoch 4 / 8]
# 100%|██████████| 100/100 [00:20<00:00,  4.81it/s]
# Epoch 4
# train_loss : 0.706839993596077
# train_accuracy : 74.930
# validation_loss : 1.135
# ...

# %% [markdown]
#  # hyperparameters ResNet9 + data augment + validation A_6
#     args.epochs = 8
#     args.learning_rate = 0.01
#     args.batch_size = 500
#     validation = 0.3

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 500
# learning_rate: 0.01
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/14 [00:00<?, ?it/s]
# [Epoch 1 / 8]
# 100%|██████████| 14/14 [00:04<00:00,  3.27it/s]
# Epoch 1
# train_loss : 2.057546692235129
# train_accuracy : 32.686
# validation_loss : 4.464
# validation_accuracy : 17.200
# [Epoch 2 / 8]
# 100%|██████████| 14/14 [00:04<00:00,  3.02it/s]
# Epoch 2
# train_loss : 1.7039600610733032
# train_accuracy : 42.129
# validation_loss : 6.809
# validation_accuracy : 25.433
# [Epoch 3 / 8]
# 100%|██████████| 14/14 [00:04<00:00,  3.30it/s]
# Epoch 3
# train_loss : 2.2467172912188937
# train_accuracy : 35.271
# validation_loss : 8.220
# validation_accuracy : 18.200
# [Epoch 4 / 8]
# 100%|██████████| 14/14 [00:04<00:00,  3.16it/s]
# Epoch 4
# train_loss : 1.4056769694600786
# train_accuracy : 49.686
# validation_loss : 2.080
# ...

# %%
# %run test.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 100%|██████████| 2500/2500 [00:14<00:00, 171.69it/s]
# Test Accuracy : 0.89270

# %% [markdown]
#  # hyperparameters ResNet9 + data augment + validation
#     args.epochs = 8
#     args.learning_rate = 0.001
#     args.batch_size = 500
#     validation = 0.3

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 500
# learning_rate: 0.001
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/14 [00:00<?, ?it/s]
# [Epoch 1 / 8]
# 100%|██████████| 14/14 [00:04<00:00,  3.27it/s]
# Epoch 1
# train_loss : 1.9722375529153007
# train_accuracy : 31.071
# validation_loss : 2.651
# validation_accuracy : 10.500
# [Epoch 2 / 8]
# 100%|██████████| 14/14 [00:04<00:00,  3.24it/s]
# Epoch 2
# train_loss : 1.3043269770486015
# train_accuracy : 52.971
# validation_loss : 3.561
# validation_accuracy : 18.600
# [Epoch 3 / 8]
# 100%|██████████| 14/14 [00:04<00:00,  3.33it/s]
# Epoch 3
# train_loss : 1.0664565478052412
# train_accuracy : 61.843
# validation_loss : 1.483
# validation_accuracy : 46.667
# [Epoch 4 / 8]
# 100%|██████████| 14/14 [00:04<00:00,  3.04it/s]
# Epoch 4
# train_loss : 0.723241789000375
# train_accuracy : 75.514
# validation_loss : 1.761
# ...

# %% [markdown]
#  # hyperparameters ResNet9 + data augment + validation
#     args.epochs = 80
#     args.learning_rate = 0.001
#     args.batch_size = 500
#     validation = 0.3

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 500
# learning_rate: 0.001
# Epochs: 80
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/14 [00:00<?, ?it/s]
# [Epoch 1 / 80]
# 100%|██████████| 14/14 [00:04<00:00,  3.27it/s]
# Epoch 1
# train_loss : 2.2748825890677318
# train_accuracy : 27.529
# validation_loss : 2.450
# validation_accuracy : 9.967
# [Epoch 2 / 80]
# 100%|██████████| 14/14 [00:04<00:00,  3.24it/s]
# Epoch 2
# train_loss : 1.498963747705732
# train_accuracy : 47.957
# validation_loss : 2.793
# validation_accuracy : 10.000
# [Epoch 3 / 80]
# 100%|██████████| 14/14 [00:04<00:00,  2.82it/s]
# Epoch 3
# train_loss : 1.2155202542032515
# train_accuracy : 60.357
# validation_loss : 2.060
# validation_accuracy : 29.400
# [Epoch 4 / 80]
# 100%|██████████| 14/14 [00:04<00:00,  3.08it/s]
# Epoch 4
# train_loss : 0.9689219210829053
# train_accuracy : 69.700
# validation_loss : 1.519
# ...

# %% [markdown]
# # hyperparameters ResNet20 + data augment + validation
#     args.epochs = 80
#     args.learning_rate = 0.001
#     args.batch_size = 500
#     validation = 0.3

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 500
# learning_rate: 0.001
# Epochs: 80
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/14 [00:00<?, ?it/s]
# [Epoch 1 / 80]
# 100%|██████████| 14/14 [00:02<00:00,  4.81it/s]
# Epoch 1
# train_loss : 2.3901067631585255
# train_accuracy : 10.057
# validation_loss : 2.317
# validation_accuracy : 10.533
# [Epoch 2 / 80]
# 100%|██████████| 14/14 [00:03<00:00,  4.33it/s]
# Epoch 2
# train_loss : 2.2440425157546997
# train_accuracy : 14.400
# validation_loss : 2.326
# validation_accuracy : 10.467
# [Epoch 3 / 80]
# 100%|██████████| 14/14 [00:02<00:00,  4.80it/s]
# Epoch 3
# train_loss : 2.123479502541678
# train_accuracy : 23.014
# validation_loss : 2.212
# validation_accuracy : 19.333
# [Epoch 4 / 80]
# 100%|██████████| 14/14 [00:02<00:00,  4.94it/s]
# Epoch 4
# train_loss : 2.0174838730267117
# train_accuracy : 26.743
# validation_loss : 2.053
# ...

# %% [markdown]
#  # hyperparameters ResNet20 + data augment + validation A_10
#     args.epochs = 8
#     args.learning_rate = 0.01
#     args.batch_size = 500
#     validation = 0.3

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 500
# learning_rate: 0.01
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/14 [00:00<?, ?it/s]
# [Epoch 1 / 8]
# 100%|██████████| 14/14 [00:10<00:00,  1.30it/s]
# Epoch 1
# train_loss : 2.0479886616979326
# train_accuracy : 23.443
# validation_loss : 3.255
# validation_accuracy : 9.733
# [Epoch 2 / 8]
# 100%|██████████| 14/14 [00:02<00:00,  5.23it/s]
# Epoch 2
# train_loss : 1.7389116712978907
# train_accuracy : 34.786
# validation_loss : 4.917
# validation_accuracy : 16.600
# [Epoch 3 / 8]
# 100%|██████████| 14/14 [00:02<00:00,  5.17it/s]
# Epoch 3
# train_loss : 1.5784607870238168
# train_accuracy : 41.043
# validation_loss : 2.992
# validation_accuracy : 25.833
# [Epoch 4 / 8]
# 100%|██████████| 14/14 [00:03<00:00,  4.36it/s]
# Epoch 4
# train_loss : 1.4138365643365043
# train_accuracy : 47.286
# validation_loss : 2.090
# ...

# %% [markdown]
#  # hyperparameters ResNet20 + validation A_11
#     args.epochs = 8
#     args.learning_rate = 0.01
#     args.batch_size = 500
#     validation = 0.3

# %%
# %matplotlib inline 
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 500
# learning_rate: 0.01
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/14 [00:00<?, ?it/s]
# [Epoch 1 / 8]
# 100%|██████████| 14/14 [00:10<00:00,  1.34it/s]
# Epoch 1
# train_loss : 2.0461537071636746
# train_accuracy : 23.543
# validation_loss : 4.100
# validation_accuracy : 10.667
# [Epoch 2 / 8]
# 100%|██████████| 14/14 [00:03<00:00,  4.21it/s]
# Epoch 2
# train_loss : 1.7360769084521703
# train_accuracy : 35.543
# validation_loss : 3.216
# validation_accuracy : 22.300
# [Epoch 3 / 8]
# 100%|██████████| 14/14 [00:02<00:00,  5.08it/s]
# Epoch 3
# train_loss : 1.5804803201130457
# train_accuracy : 41.629
# validation_loss : 6.246
# validation_accuracy : 15.333
# [Epoch 4 / 8]
# 100%|██████████| 14/14 [00:02<00:00,  5.05it/s]
# Epoch 4
# train_loss : 1.4461790238107954
# train_accuracy : 46.314
# validation_loss : 1.698
# ...

# %% [markdown]
#  # hyperparameters ResNet20 + validation + data augment _ A12
#     args.epochs = 80
#     args.learning_rate = 0.01
#     args.batch_size = 200
#     validation = 0.3

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 200
# learning_rate: 0.01
# Epochs: 80
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/35 [00:00<?, ?it/s]
# [Epoch 1 / 80]
# 100%|██████████| 35/35 [00:09<00:00,  3.59it/s]
# Epoch 1
# train_loss : 1.967631905419486
# train_accuracy : 26.871
# validation_loss : 2.748
# validation_accuracy : 11.033
# [Epoch 2 / 80]
# 100%|██████████| 35/35 [00:02<00:00, 13.05it/s]
# Epoch 2
# train_loss : 1.6010807514190675
# train_accuracy : 40.900
# validation_loss : 1.660
# validation_accuracy : 39.667
# [Epoch 3 / 80]
# 100%|██████████| 35/35 [00:02<00:00, 13.34it/s]
# Epoch 3
# train_loss : 1.4263983522142683
# train_accuracy : 47.357
# validation_loss : 1.512
# validation_accuracy : 45.300
# [Epoch 4 / 80]
# 100%|██████████| 35/35 [00:02<00:00, 11.82it/s]
# Epoch 4
# train_loss : 1.279830527305603
# train_accuracy : 52.714
# validation_loss : 2.243
# ...

# %% [markdown]
#  # hyperparameters ResNet9 + validation + data augment _ A13
#     args.epochs = 80
#     args.learning_rate = 0.01
#     args.batch_size = 20
#     validation = 0.3

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 800
# learning_rate: 0.001
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/9 [00:00<?, ?it/s]
# [Epoch 1 / 8]
# 100%|██████████| 9/9 [00:04<00:00,  2.00it/s]
# Epoch 1
# train_loss : 2.0438709788852267
# train_accuracy : 29.471
# validation_loss : 2.396
# validation_accuracy : 9.867
# [Epoch 2 / 8]
# 100%|██████████| 9/9 [00:04<00:00,  2.11it/s]
# Epoch 2
# train_loss : 1.3914725515577528
# train_accuracy : 50.771
# validation_loss : 3.638
# validation_accuracy : 11.933
# [Epoch 3 / 8]
# 100%|██████████| 9/9 [00:04<00:00,  1.95it/s]
# Epoch 3
# train_loss : 1.0994589726130168
# train_accuracy : 60.571
# validation_loss : 3.393
# validation_accuracy : 18.033
# [Epoch 4 / 8]
# 100%|██████████| 9/9 [00:04<00:00,  2.11it/s]
# Epoch 4
# train_loss : 0.7727258933915032
# train_accuracy : 73.957
# validation_loss : 2.437
# ...

# %% [markdown]
#  # hyperparameters ResNet20 + validation + data augment _ A14
#     args.epochs = 8
#     args.learning_rate = 0.001
#     args.batch_size = 400
#     validation = 0.2

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 400
# learning_rate: 0.001
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/18 [00:00<?, ?it/s]
# [Epoch 1 / 8]
# 100%|██████████| 18/18 [00:03<00:00,  5.60it/s]
# Epoch 1
# train_loss : 2.3132659991582236
# train_accuracy : 12.971
# validation_loss : 2.331
# validation_accuracy : 12.867
# [Epoch 2 / 8]
# 100%|██████████| 18/18 [00:02<00:00,  6.48it/s]
# Epoch 2
# train_loss : 1.8727898995081584
# train_accuracy : 29.886
# validation_loss : 2.077
# validation_accuracy : 24.600
# [Epoch 3 / 8]
# 100%|██████████| 18/18 [00:02<00:00,  6.48it/s]
# Epoch 3
# train_loss : 1.5939533511797588
# train_accuracy : 40.657
# validation_loss : 1.850
# validation_accuracy : 32.467
# [Epoch 4 / 8]
# 100%|██████████| 18/18 [00:02<00:00,  6.21it/s]
# Epoch 4
# train_loss : 1.4338330957624648
# train_accuracy : 46.986
# validation_loss : 1.510
# ...

# %% [markdown]
#  # hyperparameters ResNet9 + validation + data augment _ A15
#     args.epochs = 8
#     args.learning_rate = 0.001
#     args.batch_size = 800
#     validation = 0.2

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 800
# learning_rate: 0.001
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/9 [00:00<?, ?it/s]
# [Epoch 1 / 8]
# 100%|██████████| 9/9 [00:04<00:00,  2.08it/s]
# Epoch 1
# train_loss : 2.062606771787008
# train_accuracy : 27.529
# validation_loss : 2.377
# validation_accuracy : 9.867
# [Epoch 2 / 8]
# 100%|██████████| 9/9 [00:04<00:00,  2.15it/s]
# Epoch 2
# train_loss : 1.3975138266881306
# train_accuracy : 49.057
# validation_loss : 4.198
# validation_accuracy : 9.867
# [Epoch 3 / 8]
# 100%|██████████| 9/9 [00:04<00:00,  1.95it/s]
# Epoch 3
# train_loss : 1.1088607245021396
# train_accuracy : 60.500
# validation_loss : 3.755
# validation_accuracy : 14.600
# [Epoch 4 / 8]
# 100%|██████████| 9/9 [00:04<00:00,  2.11it/s]
# Epoch 4
# train_loss : 0.7678978575600518
# train_accuracy : 74.314
# validation_loss : 2.285
# ...

# %%
# %run test.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 100%|██████████| 2500/2500 [00:08<00:00, 296.77it/s]
# Test Accuracy : 0.88840

# %% [markdown]
#  # hyperparameters ResNet9 + validation + data augment _ A15
#     args.epochs = 10
#     args.learning_rate = 0.001
#     args.batch_size = 200
#     validation = 0.2

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 5
# learning_rate: 0.001
# Epochs: 20
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/1400 [00:00<?, ?it/s]
# [Epoch 1 / 20]
#  61%|██████▏   | 859/1400 [00:07<00:04, 117.81it/s]

# %% [markdown]
#  # hyperparameters ResNet20 + data augment + validation
# * args.epochs = 8
# * args.learning_rate = 0.01
# * args.batch_size = 500
# * validation = 0.3 * test

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cpu
# Number of usable GPUs: 0
# Batch_size: 5
# learning_rate: 0.01
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/1600 [00:00<?, ?it/s]
# [Epoch 1 / 8]
# 100%|██████████| 1600/1600 [01:37<00:00, 16.40it/s]
# Epoch 1
# train_loss : 1.9804596658796072
# train_accuracy : 25.900
# validation_loss : 1.782
# validation_accuracy : 33.000
# [Epoch 2 / 8]
# 100%|██████████| 1600/1600 [01:33<00:00, 17.13it/s]
# Epoch 2
# train_loss : 1.8262018804252147
# train_accuracy : 32.725
# validation_loss : 1.931
# validation_accuracy : 32.250
# [Epoch 3 / 8]
# 100%|██████████| 1600/1600 [01:34<00:00, 16.91it/s]
# Epoch 3
# train_loss : 1.6100145506300032
# train_accuracy : 40.800
# validation_loss : 1.533
# validation_accuracy : 45.500
# [Epoch 4 / 8]
# 100%|██████████| 1600/1600 [01:34<00:00, 16.84it/s]
# Epoch 4
# train_loss : 1.4219471411593259
# train_accuracy : 48.337
# ...

# %%
# %run test.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 100%|██████████| 2500/2500 [00:39<00:00, 62.92it/s]
# Test Accuracy : 0.77100

# %% [markdown]
#  # hyperparameters ResNet20 + data augment + validation
# * args.epochs = 8
# * args.learning_rate = 0.03
# * args.batch_size = 500
# * validation = 0.3 * test

# %%
# %matplotlib inline
# %run train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cpu
# Number of usable GPUs: 0
# Batch_size: 5
# learning_rate: 0.03
# Epochs: 8
# ...
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/1600 [00:00<?, ?it/s]
# [Epoch 1 / 8]
# 100%|██████████| 1600/1600 [01:26<00:00, 18.40it/s]
# Epoch 1
# train_loss : 2.0234045150876043
# train_accuracy : 24.575
# validation_loss : 2.041
# validation_accuracy : 24.600
# [Epoch 2 / 8]
# 100%|██████████| 1600/1600 [01:27<00:00, 18.39it/s]
# Epoch 2
# train_loss : 1.857758353203535
# train_accuracy : 31.488
# validation_loss : 1.727
# validation_accuracy : 36.100
# [Epoch 3 / 8]
# 100%|██████████| 1600/1600 [01:26<00:00, 18.41it/s]
# Epoch 3
# train_loss : 1.6814389866963029
# train_accuracy : 38.188
# validation_loss : 1.514
# validation_accuracy : 43.950
# [Epoch 4 / 8]
# 100%|██████████| 1600/1600 [01:29<00:00, 17.87it/s]
# Epoch 4
# train_loss : 1.4944712916389107
# train_accuracy : 45.887
# ...

# %%
# %run test.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 100%|██████████| 2500/2500 [00:37<00:00, 66.16it/s]
# Test Accuracy : 0.84440

# %%
# %run run.py
# Out:
# 100%|██████████| 7/7 [00:01<00:00,  4.96it/s]
